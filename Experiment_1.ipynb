# %% [markdown]
# <a href="https://colab.research.google.com/github/agcbls49/THESIS/blob/main/Experiment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INTRODUCTION**
# This colab file contains the model training and model comparisons of YOLOv5n, YOLOv8n, YOLOv11n and YOLOv26n using a 70% train, 20% validation and 10% test data split. For more information, you can visit this Github [repository](https://github.com/agcbls49/THESIS).
#
# <br>
#
# ---

# %% [markdown]
# # **SPECIFICATIONS**
#
# The dataset is split into **70% train, 20% valid and 10% test** and every model is trained using the following default YOLO specifications:
# 1. 100 Epochs
# 2. All images resized to 640x640
# 3. 16 Batches

# %% [markdown]
# # **SETUP**

# %% [markdown]
# ### Mounting the Dataset from Google Drive
#
# This step mounts the Google Drive where the dataset is stored and copies the dataset.zip file to Google Colab's storage allowing the dataset to be used for model training.

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# Copy dataset.zip from Drive to Colab's local storage
# !cp "/content/gdrive/MyDrive/2_THESIS_DATASET/dataset1.zip" /content/
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Unzipping the dataset contents
# This step simply unzips the content of dataset.zip in Google Colab's storage.

# %%
# Unzip the dataset folder contents
# !unzip -q /content/dataset1.zip -d /content/dataset

# %% [markdown]
# ### Installing Ultralytics for YOLO
# This step installs the ultralytics library which is needed for training YOLO models.

# %%
# Install ultralytics for YOLO
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 31.1 MB/s eta 0:00:00

# %% [markdown]
# ### Creating a YAML file
# This step creates a YAML file which is needed for training YOLO models. It contains the path of the unzipped dataset, where the train, validation and test images are located, and the names of the classes along with their class numbers.

# %%
import yaml
import os

data = {
    'path': '/content/dataset/dataset1',
    'train': 'images/train',
    'val': 'images/val',
    'test': 'images/test',
    'nc': 20,
    'names': [
        'backpack',
        'book',
        'cup',
        'glasses',
        'headphone',
        'key',
        'phone',
        'remote',
        'wallet',
        'water bottle',
        'body spray',
        'card',
        'charger',
        'comb',
        'flashlight',
        'glasses case',
        'medicine',
        'nail clipper',
        'shoe',
        'watch'
    ]
}

yaml_path = '/content/data.yaml'

# write file
with open(yaml_path, 'w') as f:
    yaml.dump(data, f)

print("written")

# verify file exists
print("exists:", os.path.exists(yaml_path))

# verify size
print("size:", os.path.getsize(yaml_path))

# print contents
with open(yaml_path, 'r') as f:
    content = f.read()

print("CONTENT:")
print(content)
# Out:
# written
# exists: True
# size: 299
# CONTENT:
# names:
# - backpack
# - book
# - cup
# - glasses
# - headphone
# - key
# - phone
# - remote
# - wallet
# - water bottle
# - body spray
# - card
# - charger
# - comb
# - flashlight
# - glasses case
# - medicine
# - nail clipper
# - shoe
# - watch
# nc: 20
# path: /content/dataset/dataset1
# test: images/test
# train: images/train
# val: images/val

# %% [markdown]
# ### **(OPTIONAL)** Deleting Conflicting Cache
#
# **This step is done only if the YOLO commands produce a YAML error otherwise this can be skipped**. <br><br> The code below deletes the cached YAML file ensuring that the code runs the proper yaml file.

# %%
# !find /content/dataset/dataset -name "*.cache" -delete

# %% [markdown]
# # **RUNNING THE MODELS**

# %% [markdown]
# ### **YOLO v5 NANO MODEL**

# %%
# !yolo detect train data=/content/data.yaml model=yolov5nu.pt epochs=100 imgsz=640 batch=16 name=yolov5n_run
# Out:
# Ultralytics 8.4.75 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov5nu.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolov5n_run-3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/yolov5n_run-3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 21.6MB/s 0.0s
# Overriding model.yaml nc=80 with nc=20
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1760  ultralytics.nn.modules.conv.Conv             [3, 16, 6, 2, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      4800  ultralytics.nn.modules.block.C3              [32, 32, 1]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     29184  ultralytics.nn.modules.block.C3              [64, 64, 2]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  3    156928  ultralytics.nn.modules.block.C3              [128, 128, 3]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1     33024  ultralytics.nn.modules.conv.Conv             [256, 128, 1, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1     90880  ultralytics.nn.modules.block.C3              [256, 128, 1, False]
#  14                  -1  1      8320  ultralytics.nn.modules.conv.Conv             [128, 64, 1, 1]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     22912  ultralytics.nn.modules.block.C3              [128, 64, 1, False]
#  18                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  19            [-1, 14]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1     74496  ultralytics.nn.modules.block.C3              [128, 128, 1, False]
#  21                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  22            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1, False]
#  24        [17, 20, 23]  1    755212  ultralytics.nn.modules.head.Detect           [20, 16, None, [64, 128, 256]]
# YOLOv5n summary: 154 layers, 2,512,364 parameters, 2,512,348 gradients, 7.2 GFLOPs
#
# Transferred 391/427 items from pretrained weights
# Freezing layer 'model.24.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 90.3MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 83.5±73.9 MB/s, size: 2018.1 KB)
# train: Scanning /content/dataset/dataset1/labels/train... 4620 images, 420 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4620/4620 362.9it/s 12.7s
# train: /content/dataset/dataset1/images/train/null_img_599.jpg: corrupt JPEG restored and saved
# train: /content/dataset/dataset1/images/train/null_img_600.jpg: corrupt JPEG restored and saved
# train: New cache created: /content/dataset/dataset1/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 325.5±451.0 MB/s, size: 2077.4 KB)
# val: Scanning /content/dataset/dataset1/labels/val... 1320 images, 120 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1320/1320 279.3it/s 4.7s
# val: New cache created: /content/dataset/dataset1/labels/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000417, momentum=0.9) with parameter groups 69 weight(decay=0.0), 76 weight(decay=0.0005), 75 bias(decay=0.0)
# Plotting labels to /content/runs/detect/yolov5n_run-3/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/yolov5n_run-3
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.13G      1.152      3.809      1.308         55        640: 100% ━━━━━━━━━━━━ 289/289 1.3s/it 6:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:25
#                    all       1320       2324        0.4      0.363      0.338      0.242
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.62G      1.137      2.779      1.287         33        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 6:00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.1s/it 1:28
#                    all       1320       2324      0.464      0.495      0.463      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.62G      1.123      2.411      1.271         47        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.1s/it 1:28
#                    all       1320       2324      0.622      0.509      0.553      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.62G      1.108      2.194      1.254         30        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:23
#                    all       1320       2324      0.595       0.55      0.578      0.411
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.62G      1.081      1.971      1.241         53        640: 100% ━━━━━━━━━━━━ 289/289 1.1s/it 5:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:23
#                    all       1320       2324      0.733      0.575      0.653       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.62G       1.06      1.795      1.224         57        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:23
#                    all       1320       2324      0.719      0.603       0.68      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.62G      1.037      1.719      1.209         41        640: 100% ━━━━━━━━━━━━ 289/289 1.1s/it 5:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:24
#                    all       1320       2324      0.732      0.658      0.714      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.62G      1.011      1.567      1.189         35        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:23
#                    all       1320       2324      0.816      0.653      0.752      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.62G      1.002      1.492       1.18         31        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:24
#                    all       1320       2324      0.742      0.673      0.728      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.62G     0.9846      1.419      1.173         22        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:33
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:26
#                    all       1320       2324      0.802      0.673      0.764      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.62G     0.9829      1.352      1.163         60        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:23
#                    all       1320       2324      0.821      0.695      0.791      0.601
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.62G     0.9588      1.278      1.154         65        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:23
#                    all       1320       2324      0.832      0.714      0.806      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.62G     0.9576      1.258      1.152         63        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:45
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:24
#                    all       1320       2324      0.801      0.728      0.803      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.62G     0.9356       1.22      1.137         23        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.1s/it 1:27
#                    all       1320       2324      0.811      0.739      0.808       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.62G     0.9352      1.164      1.135         31        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:26
#                    all       1320       2324      0.851      0.728      0.824       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.62G     0.9371       1.17      1.133         34        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:46
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:25
#                    all       1320       2324      0.835      0.752      0.828      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.62G     0.9201      1.111      1.125         34        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.9s/it 1:21
#                    all       1320       2324      0.841      0.753      0.831      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.62G     0.9082      1.096      1.122         55        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:25
#                    all       1320       2324      0.856      0.765       0.84      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.62G     0.9011      1.059      1.109         41        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:46
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.9s/it 1:21
#                    all       1320       2324      0.843      0.763      0.842      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.62G     0.9011      1.049      1.114         27        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:24
#                    all       1320       2324       0.84       0.77      0.848      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.62G     0.8869       1.03      1.104         34        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.1s/it 1:27
#                    all       1320       2324      0.877      0.768      0.854      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.62G     0.8742     0.9853      1.099         46        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:24
#                    all       1320       2324      0.848      0.769      0.852       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.62G     0.8789     0.9848      1.092         24        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 2.0s/it 1:23
#                    all       1320       2324      0.895      0.775      0.858      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.62G     0.8711     0.9732      1.094         50        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.9s/it 1:22
#                    all       1320       2324      0.872      0.773      0.854      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      2.62G     0.8569     0.9539      1.089         30        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.9s/it 1:21
#                    all       1320       2324      0.892      0.781      0.874      0.684
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.62G     0.8566     0.9342      1.087         56        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.9s/it 1:20
#                    all       1320       2324      0.887      0.792       0.88      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      2.62G      0.854     0.9282      1.083         26        640: 100% ━━━━━━━━━━━━ 289/289 1.2s/it 5:46
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.9s/it 1:20
#                    all       1320       2324      0.867      0.795      0.866      0.683
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      2.62G     0.8462     0.9232      1.078         62        640: 39% ━━━━╸─────── 114/289 2.1it/s 2:16<1:24
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 1037, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 792, in train
#     self.trainer.train()
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py", line 246, in train
#     self._do_train()
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py", line 452, in _do_train
#     loss, self.loss_items = self.model(batch)
#                             ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 143, in forward
#     return self.loss(x, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 336, in loss
#     preds = self.forward(batch["img"])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 144, in forward
#     return self.predict(x, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 161, in predict
#     return self._predict_once(x, profile, visualize, embed)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 183, in _predict_once
#     x = m(x)  # run
#         ^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/modules/block.py", line 345, in forward
#     return self.cv3(torch.cat((self.m(self.cv1(x)), self.cv2(x)), 1))
#                                                     ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/modules/conv.py", line 78, in forward
#     return self.act(self.bn(self.conv(x)))
#                     ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1783, in _call_impl
#     def _call_impl(self, *args, **kwargs):
#
# KeyboardInterrupt

# %% [markdown]
# **Run the trained model against the test images not included in the code above and print the final performance metrics.**

# %%
# !yolo detect val data=/content/data.yaml model=runs/detect/yolov5n_run/weights/best.pt split=test

# %% [markdown]
# Put the whole val folder into one file called val_results.zip and download it along with the best.pt file onto local machine.

# %%
# !zip -r val_results.zip runs/detect/val

from google.colab import files
files.download("val_results.zip")
files.download("runs/detect/yolov5n_run/weights/best.pt")

# %% [markdown]
# #### **YOLO v5 NANO RESULTS**
# Precision = <br>
# Recall = <br>
# mAP50 = <br>
# mAP50-95 = <br>
# False Alarm Rate = <br>
# Miss Rate = <br>

# %% [markdown]
# ---

# %% [markdown]
# ### **YOLO v8 NANO MODEL**

# %%
# !yolo detect train data=/content/data.yaml model=yolov8n.pt epochs=100 imgsz=640 batch=16 name=yolov8n_run

# %% [markdown]
# **Run the trained model against the test images not included in the code above and print the final performance metrics.**

# %%
# !yolo detect val data=/content/data.yaml model=runs/detect/yolov8n_run/weights/best.pt split=test

# %% [markdown]
# Put the whole val folder into one file called val_results.zip and download it along with the best.pt file onto local machine.

# %%
# !zip -r val_results.zip runs/detect/val

from google.colab import files
files.download("val_results.zip")
files.download("runs/detect/yolov8n_run/weights/best.pt")

# %% [markdown]
# #### **YOLO v8 NANO RESULTS**
# Precision = <br>
# Recall = <br>
# mAP50 = <br>
# mAP50-95 = <br>
# False Alarm Rate = <br>
# Miss Rate = <br>

# %% [markdown]
# ---

# %% [markdown]
# ### **YOLO v11 NANO MODEL**

# %%
# !yolo detect train data=/content/data.yaml model=yolo11n.pt epochs=100 imgsz=640 batch=16 name=yolo11n_run

# %% [markdown]
# **Run the trained model against the test images not included in the code above and print the final performance metrics.**

# %%
# !yolo detect val data=/content/data.yaml model=runs/detect/yolo11n_run/weights/best.pt split=test

# %% [markdown]
# Put the whole val folder into one file called val_results.zip and download it along with the best.pt file onto local machine.

# %%
# !zip -r val_results.zip runs/detect/val

from google.colab import files
files.download("val_results.zip")
files.download("runs/detect/yolo11n_run/weights/best.pt")

# %% [markdown]
# #### **YOLO v11 NANO RESULTS**
# Precision = <br>
# Recall = <br>
# mAP50 = <br>
# mAP50-95 = <br>
# False Alarm Rate = <br>
# Miss Rate = <br>

# %% [markdown]
# ---

# %% [markdown]
# ### **YOLO v26 NANO MODEL**

# %%
# !yolo detect train data=/content/data.yaml model=yolo26n.pt epochs=100 imgsz=640 batch=16 name=yolo26n_run

# %% [markdown]
# **Run the trained model against the test images not included in the code above and print the final performance metrics.**

# %%
# !yolo detect val data=/content/data.yaml model=runs/detect/yolo26n_run/weights/best.pt split=test

# %% [markdown]
# Put the whole val folder into one file called val_results.zip and download it along with the best.pt file onto local machine.

# %%
# !zip -r val_results.zip runs/detect/val

from google.colab import files
files.download("val_results.zip")
files.download("runs/detect/yolo26n_run/weights/best.pt")

# %% [markdown]
# #### **YOLO v26 NANO RESULTS**
# Precision = <br>
# Recall = <br>
# mAP50 = <br>
# mAP50-95 = <br>
# False Alarm Rate = <br>
# Miss Rate = <br>

# %% [markdown]
# ---

# %% [markdown]
# # **COMPARISON TABLE**

# %% [markdown]
# | Model | Precision | Recall | mAP50 | mAP50-95 | False Alarm Rate | Miss Rate |
# |-------|-----------|--------|-------|----------|-----------------|-----------|
# | v5n | 0% | 0% | 0% | 0% | 0% | 0% |
# | v8n | 0% | 0% | 0% | 0% | 0% | 0% |
# | v11n | 0% | 0% | 0% | 0% | 0% | 0% |
# | v26n | 0% | 0% | 0% | 0% | 0% | 0% |

# %% [markdown]
# ---
# ## **TABLE INTERPRETATION**
#
# **YOLO v5n**
# <br>
#
# **YOLO v8n**
# <br>
#
# **YOLO v11n**
# <br>
#
# **YOLO v26n**
#
# ---

# %% [markdown]
# # **CONCLUSION**
# Since the best performing model was YOLO v Nano, it is the only model to be experimented on with the configuration of epoch 100 changed into epoch 150. This will be on the [Experiment 3 & 4 colab file](https://colab.research.google.com/drive/1AE36BZFs3d6x4c7-419_y96wG4L6LFC7?usp=sharing).
