# %% [markdown]
# <a href="https://colab.research.google.com/github/agcbls49/THESIS/blob/main/Experiment_3_%26_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INTRODUCTION**
# This colab file contains the model refinement and experiment comparison of training the best model at 150 epochs and 200 epochs. For more information, you can visit this Github [repository](https://github.com/agcbls49/THESIS).
#
# <br>
#
# ---

# %% [markdown]
# Upload the best.pt file of the best model from the evaluation done in Experiment 1 and Experiment 2

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# Train the best model at 150 epochs

# %%
# !yolo detect train data=/content/data.yaml model=yolo11n.pt epochs=150 name=yolo11n_150

# %% [markdown]
# **Run the trained model against the test images not included in the code above and print the final performance metrics.**

# %%
# !yolo detect val data=/content/data.yaml model=runs/detect/yolo11n_150/weights/best.pt split=test

# %% [markdown]
# Put the whole val folder into one file called val_results.zip and download it along with the best.pt file onto local machine.

# %%
# !zip -r val_150.zip runs/detect/yolo11n_150

from google.colab import files

files.download("val_150.zip")
files.download("runs/detect/yolo11n_150/weights/best.pt")

# %% [markdown]
# #### **EPOCH 150 RESULTS**
# Precision = <br>
# Recall = <br>
# mAP50 = <br>
# mAP50-95 = <br>
# False Alarm Rate = <br>
# Miss Rate = <br>

# %% [markdown]
# ---

# %% [markdown]
# Upload the best.pt file of the best model from the evaluation done in Experiment 1 and Experiment 2

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# Train the best model at 200 epochs

# %%
# !yolo detect train data=/content/data.yaml model=yolo11n.pt epochs=200 name=yolo11n_200

# %% [markdown]
# **Run the trained model against the test images not included in the code above and print the final performance metrics.**

# %%
# !yolo detect val data=/content/data.yaml model=runs/detect/yolo11n_200/weights/best.pt split=test

# %% [markdown]
# Put the whole val folder into one file called val_results.zip and download it along with the best.pt file onto local machine.

# %%
# !zip -r val_200.zip runs/detect/yolo11n_200

from google.colab import files

files.download("val_200.zip")
files.download("runs/detect/yolo11n_200/weights/best.pt")

# %% [markdown]
# #### **EPOCH 200 RESULTS**
# Precision = <br>
# Recall = <br>
# mAP50 = <br>
# mAP50-95 = <br>
# False Alarm Rate = <br>
# Miss Rate = <br>

# %% [markdown]
# ---

# %% [markdown]
# # **COMPARISON TABLE**

# %% [markdown]
# | Model | Precision | Recall | mAP50 | mAP50-95 | False Alarm Rate | Miss Rate |
# |-------|-----------|--------|-------|----------|-----------------|-----------|
# | 100 epoch | 0% | 0% | 0% | 0% | 0% | 0% |
# | 150 epoch | 0% | 0% | 0% | 0% | 0% | 0% |
# | 200 epoch | 0% | 0% | 0% | 0% | 0% | 0% |

# %% [markdown]
# ---
# ## **TABLE INTERPRETATION**
#
# **YOLO v 100 epoch**
# <br>
#
# **YOLO v 150 epoch**
# <br>
#
# **YOLO v 200 epoch**
# <br>
#
# ---

# %% [markdown]
# # **CONCLUSION**
# Since the best performing model was YOLO v Nano trained at epoch, it will be deployed in the Android application.
